# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime as dt
# %matplotlib inline
print("Setup Complete")
# Out:
# Setup Complete

# %%
videog = ['/Users/britfathi/Downloads/video_games_global.csv', '/Users/britfathi/Downloads/video_games_regional.csv']

# %%
sales_data = pd.concat((pd.read_csv(i) for i in videog)).reset_index(drop= True)
sales_data.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    Global_Sales  NA_Sales  EU_Sales  JP_Sales  Other_Sales
# 0         82.74       NaN       NaN       NaN          NaN
# 1         40.24       NaN       NaN       NaN          NaN
# 2         35.82       NaN       NaN       NaN          NaN
# 3         33.00       NaN       NaN       NaN          NaN
# 4         31.37       NaN       NaN       NaN          NaN

# %%
sales_data.tail()
# Out:
#         Rank Name Platform  Year Genre Publisher  Global_Sales  NA_Sales  \
# 33191  16596  NaN      NaN   NaN   NaN       NaN           NaN      0.01
# 33192  16597  NaN      NaN   NaN   NaN       NaN           NaN      0.01
# 33193  16598  NaN      NaN   NaN   NaN       NaN           NaN      0.00
# 33194  16599  NaN      NaN   NaN   NaN       NaN           NaN      0.00
# 33195  16600  NaN      NaN   NaN   NaN       NaN           NaN      0.01
#
#        EU_Sales  JP_Sales  Other_Sales
# 33191      0.00       0.0          0.0
# 33192      0.00       0.0          0.0
# 33193      0.00       0.0          0.0
# 33194      0.01       0.0          0.0
# 33195      0.00       0.0          0.0

# %%
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33196 entries, 0 to 33195
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          33196 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   Global_Sales  16598 non-null  float64
#  7   NA_Sales      16598 non-null  float64
#  8   EU_Sales      16598 non-null  float64
#  9   JP_Sales      16598 non-null  float64
#  10  Other_Sales   16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 2.8+ MB

# %% [markdown]
# ## Trying to change the Year to a date instead of a float64

# %%
sales_data['Year'].replace('Year', np.nan, inplace=True)
sales_data['Year'] = pd.to_datetime(sales_data['Year'], infer_datetime_format=True)

# %%
sales_data['Year'] = sales_data['Year'].dt.year

# %%
sales_data.head(20)
# Out:
#     Rank                                          Name Platform    Year  \
# 0      1                                    Wii Sports      Wii  1970.0
# 1      2                             Super Mario Bros.      NES  1970.0
# 2      3                                Mario Kart Wii      Wii  1970.0
# 3      4                             Wii Sports Resort      Wii  1970.0
# 4      5                      Pokemon Red/Pokemon Blue       GB  1970.0
# 5      6                                        Tetris       GB  1970.0
# 6      7                         New Super Mario Bros.       DS  1970.0
# 7      8                                      Wii Play      Wii  1970.0
# 8      9                     New Super Mario Bros. Wii      Wii  1970.0
# 9     10                                     Duck Hunt      NES  1970.0
# 10    11                                    Nintendogs       DS  1970.0
# 11    12                                 Mario Kart DS       DS  1970.0
# ...

# %%
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33196 entries, 0 to 33195
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          33196 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   Global_Sales  16598 non-null  float64
#  7   NA_Sales      16598 non-null  float64
#  8   EU_Sales      16598 non-null  float64
#  9   JP_Sales      16598 non-null  float64
#  10  Other_Sales   16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 2.8+ MB
